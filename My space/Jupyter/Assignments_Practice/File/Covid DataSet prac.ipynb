# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score as cv
from sklearn.ensemble import RandomForestClassifier as rf

# %%
us_rd = pd.read_csv("D:/DS Files/DS Assingments/Exercise Excel Sheets/covid_south_america.csv")

# %%
us_rd
# Out:
#        Country/Other  Total Cases  Total Deaths  Total Recovered  \
# 0          Argentina      5305742      116232.0        5172193.0
# 1            Bolivia       523485       19017.0         482744.0
# 2             Brazil     21957967      611318.0       21151342.0
# 3              Chile      1726481       37975.0        1629572.0
# 4           Colombia      5031945      127809.0        4872420.0
# 5            Ecuador       519560       32989.0         443880.0
# 6   Falkland Islands           72           NaN             68.0
# 7      French Guiana        45366         322.0          11254.0
# 8             Guyana        36817         959.0          33504.0
# 9           Paraguay       461957       16337.0         444977.0
# 10              Peru      2214543      200635.0              NaN
# 11          Suriname        50046        1136.0          29528.0
# 12           Uruguay       396545        6101.0         388424.0
# ...

# %%
us_rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country/Other                 14 non-null     object
#  1   Total Cases                   14 non-null     int64
#  2   Total Deaths                  13 non-null     float64
#  3   Total Recovered               13 non-null     float64
#  4   Active Cases                  13 non-null     float64
#  5   Total Cases/1 mil population  14 non-null     int64
#  6   Deaths/1 mil population       13 non-null     float64
#  7   Total Tests                   14 non-null     int64
#  8   Tests/1 mil population        14 non-null     int64
#  9   Population                    14 non-null     int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.2+ KB

# %%
us_rd.isna().sum()
# Out:
# Country/Other                   0
# Total Cases                     0
# Total Deaths                    1
# Total Recovered                 1
# Active Cases                    1
# Total Cases/1 mil population    0
# Deaths/1 mil population         1
# Total Tests                     0
# Tests/1 mil population          0
# Population                      0
# dtype: int64

# %%
us_rd2 =us_rd.copy()

# %%
us_rd2
# Out:
#        Country/Other  Total Cases  Total Deaths  Total Recovered  \
# 0          Argentina      5305742      116232.0        5172193.0
# 1            Bolivia       523485       19017.0         482744.0
# 2             Brazil     21957967      611318.0       21151342.0
# 3              Chile      1726481       37975.0        1629572.0
# 4           Colombia      5031945      127809.0        4872420.0
# 5            Ecuador       519560       32989.0         443880.0
# 6   Falkland Islands           72           NaN             68.0
# 7      French Guiana        45366         322.0          11254.0
# 8             Guyana        36817         959.0          33504.0
# 9           Paraguay       461957       16337.0         444977.0
# 10              Peru      2214543      200635.0              NaN
# 11          Suriname        50046        1136.0          29528.0
# 12           Uruguay       396545        6101.0         388424.0
# ...

# %%
us_rd3 =us_rd2.dropna()

# %%
#use this dataset for buliding presiction model
us_rd3
# Out:
#     Country/Other  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 0       Argentina      5305742      116232.0        5172193.0       17317.0
# 1         Bolivia       523485       19017.0         482744.0       21724.0
# 2          Brazil     21957967      611318.0       21151342.0      195307.0
# 3           Chile      1726481       37975.0        1629572.0       58934.0
# 4        Colombia      5031945      127809.0        4872420.0       31716.0
# 5         Ecuador       519560       32989.0         443880.0       42691.0
# 7   French Guiana        45366         322.0          11254.0       33790.0
# 8          Guyana        36817         959.0          33504.0        2354.0
# 9        Paraguay       461957       16337.0         444977.0         643.0
# 11       Suriname        50046        1136.0          29528.0       19382.0
# 12        Uruguay       396545        6101.0         388424.0        2020.0
# ...

# %%
us_rd3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 13
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country/Other                 12 non-null     object
#  1   Total Cases                   12 non-null     int64
#  2   Total Deaths                  12 non-null     float64
#  3   Total Recovered               12 non-null     float64
#  4   Active Cases                  12 non-null     float64
#  5   Total Cases/1 mil population  12 non-null     int64
#  6   Deaths/1 mil population       12 non-null     float64
#  7   Total Tests                   12 non-null     int64
#  8   Tests/1 mil population        12 non-null     int64
#  9   Population                    12 non-null     int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.0+ KB

# %%
#divide our data into input and output varibales.
x = us_rd3.iloc[:,1:]
y = us_rd3.iloc[:,0]

# %%
num_tree = 100
max_features = 3
kfold = KFold(n_splits=5)
model = rf(n_estimators=num_tree,max_features=max_features)
cross_val = cv(model,x,y,cv=kfold)

# %%
print(cross_val.mean())
# Out:
# 0.0
