# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.spatial.distance import cdist
import numpy as np

# %%
k_rd = pd.read_csv("D:/DS Files/DS Assingments/Excel Data Sheets/Universities.csv")

# %%
k_rd
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
#normalization built _in function 
def norm(x):
    res = (x-x.min())/(x.max()-x.min())
    return res

# %%
k_norm = norm(k_rd.iloc[:,1:])
k_norm
# Out:
#          SAT     Top10    Accept   SFRatio  Expenses  GradRate
# 0   0.743902  0.847222  0.105263  0.368421  0.255144  0.900000
# 1   1.000000  1.000000  0.144737  0.000000  1.000000  0.466667
# 2   0.621951  0.472222  0.592105  0.157895  0.297461  0.166667
# 3   0.743902  0.666667  0.131579  0.315789  0.415629  0.700000
# 4   0.670732  0.763889  0.250000  0.368421  0.239835  0.766667
# 5   0.817073  0.847222  0.118421  0.210526  0.427512  0.933333
# 6   0.756098  0.861111  0.210526  0.315789  0.416996  0.933333
# 7   0.609756  0.638889  0.131579  0.315789  0.208161  0.833333
# 8   0.963415  0.875000  0.000000  0.263158  0.561699  1.000000
# 9   0.731707  0.652778  0.394737  0.052632  0.910991  0.666667
# 10  0.914634  0.916667  0.210526  0.210526  0.476864  0.800000
# 11  0.621951  0.791667  0.328947  0.263158  0.352609  0.733333
# 12  0.609756  0.736111  0.368421  0.368421  0.116965  0.900000
# 13  0.185366  0.138889  0.526316  0.631579  0.026991  0.433333
# ...

# %%
k_clust = KMeans(n_clusters=5)
k_clust.fit(k_norm)
# Out:
# KMeans(n_clusters=5)

# %%
k_lb = k_clust.labels_
k_lb
# Out:
# array([2, 1, 0, 2, 2, 4, 4, 2, 4, 1, 4, 2, 2, 3, 4, 3, 4, 3, 0, 2, 0, 2,
#        2, 3, 4])

# %%
cd = k_clust.cluster_centers_[0:4]
cd
# Out:
# array([[0.54065041, 0.63888889, 0.54824561, 0.42105263, 0.179354  ,
#         0.37777778],
#        [0.86585366, 0.82638889, 0.26973684, 0.02631579, 0.95549562,
#         0.56666667],
#        [0.65718157, 0.72222222, 0.2748538 , 0.33918129, 0.28414929,
#         0.78888889],
#        [0.13780488, 0.14930556, 0.73684211, 0.69736842, 0.02276248,
#         0.15833333]])

# %%
cd[0].reshape(1,6)
#k_clust.labels_
# Out:
# array([[0.54065041, 0.63888889, 0.54824561, 0.42105263, 0.179354  ,
#         0.37777778]])

# %%
k_rd['Cluster_id'] = pd.Series(k_clust.labels_)

# %%
k_rd
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate  Cluster_id
# 0          Brown  1310     89      22       13     22704        94           2
# 1        CalTech  1415    100      25        6     63575        81           1
# 2            CMU  1260     62      59        9     25026        72           0
# 3       Columbia  1310     76      24       12     31510        88           2
# 4        Cornell  1280     83      33       13     21864        90           2
# 5      Dartmouth  1340     89      23       10     32162        95           4
# 6           Duke  1315     90      30       12     31585        95           4
# 7     Georgetown  1255     74      24       12     20126        92           2
# 8        Harvard  1400     91      14       11     39525        97           4
# 9   JohnsHopkins  1305     75      44        7     58691        87           1
# 10           MIT  1380     94      30       10     34870        91           4
# ...

# %%
k = list(range(1,11))
Twss = [] #for storing total sum of squares for each k means
for i in k:
    kmean = KMeans(n_clusters=i)
    kmean.fit(k_norm)
    #print(i)
# Out:
# E:\ANACONDA\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
cd = cdist(k_norm.iloc[kmean.labels_==j,:],kmean.cluster_centers_[j].reshape(1,k_norm.shape[1]))

# %%
cd

# %%
Wss = []
for j in range(i):
    Wss.append(sum(cdist()))
